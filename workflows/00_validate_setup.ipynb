# %% [markdown]
# # 00 — Validate Neurodesk setup
#
# Quick sanity check that the tools we need for the MS workshop are available inside Neurodesk.
#
# Run each cell top to bottom. Every command should print a version number — no errors.

# %% [markdown]
# ## FSL

# %%
# %%bash
# ml load fsl
# flirt -version
# bet2 --help 2>&1 | head -1

# %% [markdown]
# ## FreeSurfer

# %%
# %%bash
# ml load freesurfer
# mri_convert --version
# echo "SUBJECTS_DIR=$SUBJECTS_DIR"

# %% [markdown]
# ## ANTs

# %%
# %%bash
# ml load ants
# antsRegistration --version
# N4BiasFieldCorrection --version

# %% [markdown]
# ## MRtrix3

# %%
# %%bash
# ml load mrtrix3
# mrconvert -version | head -3

# %% [markdown]
# ## Spinal Cord Toolbox

# %%
# %%bash
# ml load spinalcordtoolbox || echo "SCT module name may differ — try: ml avail | grep -i spinal"
# sct_version 2>/dev/null || echo "Skipping if not installed"

# %% [markdown]
# ## Python packages
#
# Useful for the rest of the workshop:

# %%
import nibabel, numpy, matplotlib, nilearn
print('nibabel', nibabel.__version__)
print('numpy', numpy.__version__)
print('matplotlib', matplotlib.__version__)
print('nilearn', nilearn.__version__)

# %% [markdown]
# If everything ran cleanly, you're ready for the workshop.
#
# If anything failed, check `../setup/README.md` or run `ml avail` in a terminal to see which modules exist.
